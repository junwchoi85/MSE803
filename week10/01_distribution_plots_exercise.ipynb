# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd

# Load the data from csv using pandas
df = pd.read_csv('Sample_Data_for_Activity.csv')

# %%
# Use the seaborn library to create a scatter plot
sns.scatterplot(x='Normal_Distribution', y='Uniform_Distribution', data=df)
# Out:
# <Axes: xlabel='Normal_Distribution', ylabel='Uniform_Distribution'>

# %%
sns.displot(df['Normal_Distribution'], kde=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Normal_Distribution       1000 non-null   float64
#  1   Uniform_Distribution      1000 non-null   float64
#  2   Exponential_Distribution  1000 non-null   float64
#  3   Poisson_Distribution      1000 non-null   int64
# dtypes: float64(3), int64(1)
# memory usage: 31.4 KB

# %%
df.head(-2)
# Out:
#      Normal_Distribution  Uniform_Distribution  Exponential_Distribution  \
# 0              57.450712             30.048955                  2.472682
# 1              47.926035             26.274070                  0.374126
# 2              59.715328             58.185815                  1.143180
# 3              72.845448             62.388544                  4.137906
# 4              46.487699             21.895169                 16.224506
# ..                   ...                   ...                       ...
# 993            39.770236             31.765863                  2.274939
# 994            34.975700             56.646804                  0.693218
# 995            45.783496             36.840993                 20.984242
# 996            76.965298             32.419555                  4.933213
# 997            59.612643             50.994358                  7.803643
#
#      Poisson_Distribution
# 0                       4
# 1                       5
# ...

# %%
rows, cols = df.shape
print(f"Number of rows: {rows}")
print(f"Number of columns: {cols}")
# Out:
# Number of rows: 1000
# Number of columns: 4

# %%
sns.displot(df['Uniform_Distribution'], kde=True)

# %%
sns.displot(df['Exponential_Distribution'], kde=True)

# %%
sns.displot(df['Poisson_Distribution'], kde=True)

# %%
# Joint plot exercise
sns.jointplot(x='Normal_Distribution', y='Uniform_Distribution', data=df, kind='hex')

# %%
# pairplot exercise
sns.pairplot(df)

# %%
# rugplot exercise
sns.histplot(df['Normal_Distribution'], kde=True)
sns.rugplot(df['Normal_Distribution'])
# Out:
# <Axes: xlabel='Normal_Distribution', ylabel='Count'>

# %%
#kdeplots exercise
sns.kdeplot(df['Normal_Distribution'], shade=True)
# Out:
# /var/folders/1k/jvyhg6t92v745x10cfh8vjkm0000gn/T/ipykernel_9253/1452540935.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Normal_Distribution'], shade=True)
# <Axes: xlabel='Normal_Distribution', ylabel='Density'>
